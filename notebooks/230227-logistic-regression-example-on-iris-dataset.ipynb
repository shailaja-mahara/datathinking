# %% [markdown]
# # questions
# * how do you create a jupyter notebook?
#   * click on the help menu, type in notebook, click on create new jupyter notebook
#   * open the "command palette" in visual studio code
#   * https://code.visualstudio.com/docs/datascience/jupyter-notebooks
#
# # plan
# - [x] load the iris data set
# - [x] plot the data
# - [ ] write the math for logistic regression
# - [ ] test logistic regression model
# - [ ] plot the results
# * learn embeddings
# * learn transformers & attention
# * learn chatgpt
# * -- new words are confusing, and it takes time to learn how to use them. it's okay to not know what words mean, to still use them and program with them, and learn through experience.
#
# # common gotchas
# * unclear which python interpreter `pip install -U scikit-learn scipy matplotlib` installs things to
#   * `python -m pip install -U scikit-learn scipy matplotlib`
#   * `python3 -m pip install -U scikit-learn scipy matplotlib`
#   * `python3.8 -m pip install -U scikit-learn scipy matplotlib`
#   * `python3.9 -m pip install -U scikit-learn scipy matplotlib`

# %%
# import the required libraries
from sklearn import datasets
from matplotlib import pyplot as plt

# %%
# plot the iris data set
def plot_iris_data():
    # load the iris data set
    iris = datasets.load_iris()
    # get the data
    X = iris.data
    # get the target
    y = iris.target
    # get the feature names
    feature_names = iris.feature_names
    # get the target names
    target_names = iris.target_names
    # create a figure
    fig = plt.figure(figsize=(8, 6))
    # create a scatter plot
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
    # set the x and y axis labels
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    # set the title
    plt.title('Iris Data Set')
    # show the plot
    plt.show()

# %%
plot_iris_data()

# %%
# build logistic regression model
def build_logistic_regression_model():
